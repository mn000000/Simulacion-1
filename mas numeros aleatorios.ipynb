# %% [markdown]
# <a href="https://colab.research.google.com/github/mn000000/Simulacion-1/blob/main/mas%20numeros%20aleatorios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Uso de los números aleatorios

# %% [markdown]
# ## 1. Introducción al Módulo random

# %% [markdown]
# El módulo random de la librería estándar de Python incluye un conjunto de funciones que permiten obtener de distintos modos
# números pseudoaleatorios a través del algoritmo [Mersenne Twister](https://es.wikipedia.org/wiki/Mersenne_twister).

# %%
#importamos el módulo que vamos a usar

import random
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Las funciones de los módulos se invocan con el formato: módulo.función().
#
# En el módulo random existe la función random, que devuelve un número aleatorio que sigue una distribución uniforme.
#
# Así, para obtener $x \sim U(0,1)$:

# %%
x = random.random()  #Cada ejecución dará un número distinto.
print(x)
# Out:
# 0.2631576340655931

# %% [markdown]
# Se puede usar algún bucle si se desea generar una secuencia $x_i \sim U(0,1)$ con $i = 1, 2, 3,..., N$:

# %%
for i in range(10):
    print('%05.4f' % random.random(), end=' ')  #El código en rojo indica la cantidad de dígitos y de decimales a mostrar.
print()
# Out:
# 0.8051 0.0334 0.0810 0.6119 0.2995 0.6544 0.2477 0.3176 0.9834 0.9200

# %%
for i in range(10):
    print('%05.4f' % random.random(), sep="\t")
print()
# Out:
# 0.4031
# 0.7344
# 0.2941
# 0.0726
# 0.5098
# 0.3411
# 0.9141
# 0.3481
# 0.7180
# 0.0607

# %% [markdown]
# La función seed() fija el valor de la semilla en la generación de la secuencia de números aleatorios.
# Esto es útil cuando se quieren utilizar los mismos datos de entrada en una simulación.

# %%
random.seed(1) #primero fijamos la semilla

for i in range(20):
    print('%05.4f' % random.random(), end=' ')
print()
# Out:
# 0.1344 0.8474 0.7638 0.2551 0.4954 0.4495 0.6516 0.7887 0.0939 0.0283 0.8358 0.4328 0.7623 0.0021 0.4454 0.7215 0.2288 0.9453 0.9014 0.0306

# %% [markdown]
# La función uniform() devuelve un número float incluido entre los valores indicados.

# %%
for i in range(10):
    print('%5.4f' %random.uniform(1, 50), end=' ')
print()
# Out:
# 2.2468 27.5292 47.0183 19.6790 11.6134 21.6837 2.4230 11.8629 22.4565 25.2948

# %% [markdown]
# La función randint() devuelve un número entero incluido entre los valores indicados.
# Los valores de los límites inferior y superior también pueden aparecer entre los valores devueltos.

# %%
for i in range(20):
    print(random.randint(-100, 100), end=' ')
print()
# Out:
# -41 -12 -41 73 -44 94 17 -26 -95 6 42 64 -75 -53 61 85 -25 -70 90 -15

# %% [markdown]
# La función randrange() devuelve enteros que van desde un valor inicial a otro final
# separados entre sí un número de valores determinados.

# %%
for i in range(20):
    print(random.randrange(0, 20, 3), end=' ')
print()
# Out:
# 3 0 18 3 12 18 12 3 9 12 6 18 12 6 9 6 15 12 12 15

# %% [markdown]
# La función random.choice() se utiliza para seleccionar elementos al azar de una lista.

# %%
Lista = ['Rome','New York','London','Berlin','Moskov', 'Los Angeles','Paris','Madrid','Tokio','Toronto']

# %%
Ciudad = random.choice(Lista)
print ("La ciudad elegida es - ", Ciudad)
# Out:
# La ciudad elegida es -  Rome

# %%
for i in range(10):
    Ciudad = random.choice(Lista)
    print ("La ciudad elegida es - ", Ciudad)
# Out:
# La ciudad elegida es -  Paris
# La ciudad elegida es -  Tokio
# La ciudad elegida es -  London
# La ciudad elegida es -  Tokio
# La ciudad elegida es -  Tokio
# La ciudad elegida es -  Berlin
# La ciudad elegida es -  Paris
# La ciudad elegida es -  Rome
# La ciudad elegida es -  Madrid
# La ciudad elegida es -  Los Angeles

# %% [markdown]
# La función sample() devuelve de una lista de elementos un determinado número de elementos diferentes elegidos al azar.

# %%
print(random.sample(Lista, 9))
# Out:
# ['Toronto', 'Tokio', 'Berlin', 'Moskov', 'Madrid', 'Los Angeles', 'London', 'New York', 'Paris']

# %% [markdown]
# La función shuffle() 'mezcla' o cambia aleatoriamente el orden de los elementos de una lista antes de realizar la selección de alguno de ellos.

# %%
random.shuffle(Lista)
print('mezcla1', Lista)
# Out:
# mezcla1 ['Paris', 'Madrid', 'London', 'New York', 'Toronto', 'Moskov', 'Berlin', 'Los Angeles', 'Tokio', 'Rome']

# %% [markdown]
# ## Ejercicio:
#
# 1. Elegir al azar una ciudad de la Lista despues de hacer una mezcla.
# 2. Elegir al azar tres ciudades después de una mezcla.

# %%
#1
random.shuffle(Lista)
print(random.sample(Lista, 1))
#2
random.shuffle(Lista)
print(random.sample(Lista, 3))
# Out:
# ['Moskov']
# ['Moskov', 'London', 'Paris']

# %% [markdown]
# La función random.gaus() genera una muestra de números aleatorios normalmente distribuidos.

# %%
#Generamos una lista de 100 números aleatorios normalmente distribuidos.

nums = []
mu = 100
sigma = 50

for i in range(100):
    temp = random.gauss(mu, sigma)
    nums.append(temp)

plt.plot(nums)
plt.show()

# %%
# Construimos el histograma de una muestra de 10000 números aleatorios normalmente distribuidos

nums = []
mu = 100
sigma = 50

for i in range(10000):
    temp = random.gauss(mu, sigma)
    nums.append(temp)

plt.hist(nums, bins = 200)
plt.show()

# %% [markdown]
# ## Ejercicio:
#
# 1. Generar muestras e histograma de las funciones:
#     triangular(), betavariate(), expovariate(), gammavariate(),
#     lognormvariate(), normalvariate(), vonmisesvariate(), paretovariate() y weibullvariate()

# %%
import random
import matplotlib.pyplot as plt

# Distribución triangular
nums_triangular = []
for i in range(100):
    temp = random.triangular(0, 100, 50)
    nums_triangular.append(temp)
plt.plot(nums_triangular)
plt.title('Distribución Triangular (100 muestras)')
plt.show()

nums_triangular_extended = []
for i in range(2000):
    temp = random.triangular(0, 100, 50)
    nums_triangular_extended.append(temp)
plt.hist(nums_triangular_extended, bins=200)
plt.title('Histograma de Distribución Triangular (2000 muestras)')
plt.show()

# Distribución betavariate
nums_betavariate = []
for i in range(100):
    temp = random.betavariate(2, 5)
    nums_betavariate.append(temp)
plt.plot(nums_betavariate)
plt.title('Distribución Betavariate (100 muestras)')
plt.show()

nums_betavariate_extended = []
for i in range(2000):
    temp = random.betavariate(2, 5)
    nums_betavariate_extended.append(temp)
plt.hist(nums_betavariate_extended, bins=200)
plt.title('Histograma de Distribución Betavariate (2000 muestras)')
plt.show()

# Distribución expovariate
nums_expovariate = []
for i in range(100):
    temp = random.expovariate(0.5)
    nums_expovariate.append(temp)
plt.plot(nums_expovariate)
plt.title('Distribución Expovariate (100 muestras)')
plt.show()

nums_expovariate_extended = []
for i in range(2000):
    temp = random.expovariate(0.5)
    nums_expovariate_extended.append(temp)
plt.hist(nums_expovariate_extended, bins=200)
plt.title('Histograma de Distribución Expovariate (2000 muestras)')
plt.show()

# Distribución gammavariate
nums_gammavariate = []
for i in range(100):
    temp = random.gammavariate(2, 2)
    nums_gammavariate.append(temp)
plt.plot(nums_gammavariate)
plt.title('Distribución Gammavariate (100 muestras)')
plt.show()

nums_gammavariate_extended = []
for i in range(2000):
    temp = random.gammavariate(2, 2)
    nums_gammavariate_extended.append(temp)
plt.hist(nums_gammavariate_extended, bins=200)
plt.title('Histograma de Distribución Gammavariate (2000 muestras)')
plt.show()

# Distribución lognormvariate
nums_lognormvariate = []
for i in range(100):
    temp = random.lognormvariate(0, 1)
    nums_lognormvariate.append(temp)
plt.plot(nums_lognormvariate)
plt.title('Distribución Lognormvariate (100 muestras)')
plt.show()

nums_lognormvariate_extended = []
for i in range(2000):
    temp = random.lognormvariate(0, 0.05)
    nums_lognormvariate_extended.append(temp)
plt.hist(nums_lognormvariate_extended, bins=200)
plt.title('Histograma de Distribución Lognormvariate (2000 muestras)')
plt.show()

# Distribución normalvariate
nums_normalvariate = []
for i in range(100):
    temp = random.normalvariate(0, 1)
    nums_normalvariate.append(temp)
plt.plot(nums_normalvariate)
plt.title('Distribución Normalvariate (100 muestras)')
plt.show()

nums_normalvariate_extended = []
for i in range(2000):
    temp = random.normalvariate(0, 1)
    nums_normalvariate_extended.append(temp)
plt.hist(nums_normalvariate_extended, bins=200)
plt.title('Histograma de Distribución Normalvariate (2000 muestras)')
plt.show()

# Distribución vonmisesvariate
nums_vonmisesvariate = []
for i in range(100):
    temp = random.vonmisesvariate(0, 2)
    nums_vonmisesvariate.append(temp)
plt.plot(nums_vonmisesvariate)
plt.title('Distribución Vonmisesvariate (100 muestras)')
plt.show()

nums_vonmisesvariate_extended = []
for i in range(2000):
    temp = random.vonmisesvariate(0, 2)
    nums_vonmisesvariate_extended.append(temp)
plt.hist(nums_vonmisesvariate_extended, bins=200)
plt.title('Histograma de Distribución Vonmisesvariate (2000 muestras)')
plt.show()

# Distribución paretovariate
nums_paretovariate = []
for i in range(100):
    temp = random.paretovariate(3)
    nums_paretovariate.append(temp)
plt.plot(nums_paretovariate)
plt.title('Distribución Paretovariate (100 muestras)')
plt.show()

nums_paretovariate_extended = []
for i in range(2000):
    temp = random.paretovariate(3)
    nums_paretovariate_extended.append(temp)
plt.hist(nums_paretovariate_extended, bins=200)
plt.title('Histograma de Distribución Paretovariate (2000 muestras)')
plt.show()

# Distribución weibullvariate
nums_weibullvariate = []
for i in range(100):
    temp = random.weibullvariate(3, 1)
    nums_weibullvariate.append(temp)
plt.plot(nums_weibullvariate)
plt.title('Distribución Weibullvariate (100 muestras)')
plt.show()

nums_weibullvariate_extended = []
for i in range(2000):
    temp = random.weibullvariate(3, 1)
    nums_weibullvariate_extended.append(temp)
plt.hist(nums_weibullvariate_extended, bins=200)
plt.title('Histograma de Distribución Weibullvariate (2000 muestras)')
plt.show()

# %% [markdown]
# ## Podemos simular diversas variables aleatorias a partir de un generador de números aleatorios (uniformemente distribuidos).

# %% [markdown]
# ### La distribución exponencial
#
# Función de densidad:
#
# $f_X (x) = \lambda e^{-\lambda x}$  para $x \geq 0$
#
# y función de distribución:
#
# $F_X (x) = 1 - e^{-\lambda x}$  para $x \geq 0$

# %% [markdown]
# Puede ser simulada por el método de inversión mediante el siguiente algoritmo:
#
# 0. Hacer $L = -\frac{1}{\lambda}$
# 1. Generar $U \sim U(0, 1)$
# 2. Devolver $X = L \cdot Ln(U)$

# %%
import random                                   # importamos el módulo random
import numpy as np                              # importamos numpy con un alias (np)
import matplotlib.pyplot as plt                 # ídem
#from random import expovariate, gauss
from statistics import mean, median, variance, stdev      # exportamos funciones especificas de statistics

# %%
#Generamos una lista de números aleatorios que siguen la distribución exponencial.

nums = []
lamb = 0.01                                     # Párametro de la función exponencial
L = -1.0/lamb #inversa de lambda

for i in range(100):
    temp = L*np.log(random.random())            # Pasos 1 y 2
    nums.append(temp)

plt.plot(nums)
plt.show()

# %%
nums = []
lamb = 0.01                                     # Párametro de la función exponencial
L = -1.0/lamb #inversa de lambda

for i in range(1000):
    temp = L*np.log(random.random())
    nums.append(temp)

plt.hist(nums, bins = 100)
plt.show()

# %% [markdown]
# ### Lo podemos comparar con la salida de la función expovariate()

# %%
# Construimos el histograma de una muestra de 10000 números aleatorios normalmente distribuidos

nums = []
lamb = 0.01


for i in range(1000):
    temp = random.expovariate(lamb)
    nums.append(temp)

plt.hist(nums, bins = 100)
plt.show()

# %% [markdown]
# Que se puede obtener de esta otra manera:

# %%
#plt.figure(figsize = (8, 4))
plt.hist([random.expovariate(100) for i in range(10000)], bins = 200)
plt.show()

# %% [markdown]
# Y podemos usar el módulo statistics para obtener algunos parámetros del histograma.

# %%
#plt.figure(figsize = (8, 4))
sample = [random.expovariate(0.01) for i in range(1000)]
plt.hist(sample, bins = 200)
plt.show()

print(f'Media: {mean(sample):.5f}.  Mediana: {median(sample):.5f}.')
print(f'Varianza: {variance(sample):.5f}.  Desviación estándar: {stdev(sample):.5f}.')
# Out:
# Media: 99.27893.  Mediana: 73.78533.
# Varianza: 9275.49215.  Desviación estándar: 96.30936.

# %% [markdown]
# ## Ejercicio (03032022):
#
# Simular dos distribuciones de probabilidad (no la normal, no la exponencial), por el método que prefieran.

# %%
import random
import matplotlib.pyplot as plt

# Definimos una función para simular una distribución utilizando el método del producto medio con dígitos centrales
def simulate_distribution(num_samples):
    # Creamos una lista para almacenar los resultados de la simulación
    results = []

    # Iteramos sobre el número de muestras deseado
    for _ in range(num_samples):
        # Generamos dos números aleatorios entre 0 y 1
        u1 = random.random()
        u2 = random.random()

        # Calculamos el producto de los dos números aleatorios
        product = u1 * u2

        # Convertimos el producto a una cadena de texto para obtener sus dígitos
        product_str = str(product)

        # Calculamos el índice del dígito central
        mid_index = len(product_str) // 2

        # Tomamos los tres dígitos centrales alrededor del índice central
        mid_digits = product_str[mid_index-1:mid_index+2]

        # Convertimos los dígitos centrales nuevamente en un número flotante y lo añadimos a los resultados
        result = float(mid_digits)
        results.append(result)

    # Devolvemos la lista de resultados
    return results

# Simulamos dos distribuciones utilizando el método del producto medio con dígitos centrales
samples_distribution1 = simulate_distribution(1000)
samples_distribution2 = simulate_distribution(1000)

# Visualizamos las distribuciones generadas utilizando histogramas
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.hist(samples_distribution1, bins=50, color='blue', alpha=0.7)
plt.title('Distribución 1 (Producto Medio con Dígitos Centrales)')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.ylim(0, 30)  # Establecemos los límites del eje y

plt.subplot(1, 2, 2)
plt.hist(samples_distribution2, bins=50, color='red', alpha=0.7)
plt.title('Distribución 2 (Producto Medio con Dígitos Centrales)')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.ylim(0, 30)  # Establecemos los límites del eje y

plt.tight_layout()
plt.show()
